# %% [markdown]
# # Credit Card Dataset EDA

# %%
# Basic EDA imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.preprocessing import StandardScaler


pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 999)

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %matplotlib inline

# %%
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62      0
# 1    2.69      0
# 2  378.66      0
# 3  123.50      0
# 4   69.99      0

# %%
# Checking Counts
df['Class'].value_counts()
# 0 = Not Fraudulent
# 1 = Fraudulent Transaction
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df['Class'].value_counts(normalize=True)
# 0 = Not Fraudulent
# 1 = Fraudulent Transaction
# Out:
# 0    0.998273
# 1    0.001727
# Name: Class, dtype: float64

# %% [markdown]
# - 99.83% of Transactions were ok
# - 0.17% of Transactions were fraudulent

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  3.919560e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  5.688174e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -8.769071e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.782312e-15      1.415869   -5.683171     -0.848640
# V5      284807.0 -1.552563e-15      1.380247 -113.743307     -0.691597
# V6      284807.0  2.010663e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -1.694249e-15      1.237094  -43.557242     -0.554076
# V8      284807.0 -1.927028e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -3.137024e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  1.768627e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  9.170318e-16      1.020713   -4.797473     -0.762494
# V12     284807.0 -1.810658e-15      0.999201  -18.683715     -0.405571
# V13     284807.0  1.693438e-15      0.995274   -5.791881     -0.648539
# V14     284807.0  1.479045e-15      0.958596  -19.214325     -0.425574
# V15     284807.0  3.482336e-15      0.915316   -4.498945     -0.582884
# V16     284807.0  1.392007e-15      0.876253  -14.129855     -0.468037
# V17     284807.0 -7.528491e-16      0.849337  -25.162799     -0.483748
# V18     284807.0  4.328772e-16      0.838176   -9.498746     -0.498850
# V19     284807.0  9.049732e-16      0.814041   -7.213527     -0.456299
# V20     284807.0  5.085503e-16      0.770925  -54.497720     -0.211721
# V21     284807.0  1.537294e-16      0.734524  -34.830382     -0.228395
# V22     284807.0  7.959909e-16      0.725702  -10.933144     -0.542350
# V23     284807.0  5.367590e-16      0.624460  -44.807735     -0.161846
# V24     284807.0  4.458112e-15      0.605647   -2.836627     -0.354586
# V25     284807.0  1.453003e-15      0.521278  -10.295397     -0.317145
# V26     284807.0  1.699104e-15      0.482227   -2.604551     -0.326984
# V27     284807.0 -3.660161e-16      0.403632  -22.565679     -0.070840
# V28     284807.0 -1.206049e-16      0.330083  -15.430084     -0.052960
# Amount  284807.0  8.834962e+01    250.120109    0.000000      5.600000
# Class   284807.0  1.727486e-03      0.041527    0.000000      0.000000
#
#                  50%            75%            max
# Time    84692.000000  139320.500000  172792.000000
# V1          0.018109       1.315642       2.454930
# V2          0.065486       0.803724      22.057729
# V3          0.179846       1.027196       9.382558
# V4         -0.019847       0.743341      16.875344
# V5         -0.054336       0.611926      34.801666
# V6         -0.274187       0.398565      73.301626
# V7          0.040103       0.570436     120.589494
# V8          0.022358       0.327346      20.007208
# V9         -0.051429       0.597139      15.594995
# V10        -0.092917       0.453923      23.745136
# V11        -0.032757       0.739593      12.018913
# V12         0.140033       0.618238       7.848392
# V13        -0.013568       0.662505       7.126883
# V14         0.050601       0.493150      10.526766
# V15         0.048072       0.648821       8.877742
# V16         0.066413       0.523296      17.315112
# V17        -0.065676       0.399675       9.253526
# V18        -0.003636       0.500807       5.041069
# V19         0.003735       0.458949       5.591971
# V20        -0.062481       0.133041      39.420904
# V21        -0.029450       0.186377      27.202839
# V22         0.006782       0.528554      10.503090
# V23        -0.011193       0.147642      22.528412
# V24         0.040976       0.439527       4.584549
# V25         0.016594       0.350716       7.519589
# V26        -0.052139       0.240952       3.517346
# V27         0.001342       0.091045      31.612198
# V28         0.011244       0.078280      33.847808
# Amount     22.000000      77.165000   25691.160000
# Class       0.000000       0.000000       1.000000

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df['Time'].value_counts()
# Out:
# 163152.0    36
# 64947.0     26
# 68780.0     25
# 3767.0      21
# 3770.0      20
#             ..
# 2088.0       1
# 64100.0      1
# 42068.0      1
# 119630.0     1
# 140344.0     1
# Name: Time, Length: 124592, dtype: int64

# %%
# Raw Data Correlation

mask = np.zeros_like(df.corr())
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(36,30))
sns.heatmap(df.corr(), annot=True, vmin=-1, vmax=1, mask=mask, cmap='Spectral')

b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values

plt.savefig('images/heatmapall.png')

# %%
# Correlation against 'Class'
plt.figure(figsize=(8,24))
sns.heatmap(df.corr()[['Class']].sort_values(by='Class', ascending=False), annot=True, vmin=-1, vmax=1, cmap='Spectral')
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
#Vmin and Vmax are making it so it diverges on 0, not how it was

plt.savefig('images/heatmapclass.png')

# %% [markdown]
# - Oversampling
# - Undersampling
# - Weights

# %%
len(df[df['Class'] == 0])
# Out:
# 284315

# %%
len(df[df['Class'] == 1])
# Out:
# 492

# %%
plt.figure(figsize=(15,7))

plt.style.use('fivethirtyeight')
# df2['Class'].value_counts().plot(kind='barh')
sns.countplot(y='Class', data=df);
plt.title('Count of Classes');
plt.xlabel('');

# %% [markdown]
# # Create Oversampling Dataset

# %%
df.shape
# Out:
# (284807, 31)

# %%
amt = len(df[df['Class'] == 0]) - len(df[df['Class'] == 1])
amt
# Out:
# 283823

# %%
df_sample = df[df['Class'] == 1].sample(amt, replace=True, random_state=42)

# %%
df2 = pd.concat([df, df_sample])

# %%
df2.shape
# Out:
# (568630, 31)

# %%
# Correlation against 'Class'
plt.figure(figsize=(8,24))
sns.heatmap(df2.corr()[['Class']].drop(index=['Class','Time','Amount']).sort_values(by='Class', ascending=False), annot=True, vmin=-1, vmax=1, cmap='Spectral')
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
#Vmin and Vmax are making it so it diverges on 0, not how it was

plt.savefig('images/heatmapclass2.png')

# %%
# 5 Negative Correlation Variables
fig, axes = plt.subplots(ncols=5, figsize=(20,8))

sns.boxplot(x="Class", y="V14", data=df2, ax=axes[0])
axes[0].set_title('V14')

sns.boxplot(x="Class", y="V12", data=df2, ax=axes[1])
axes[1].set_title('V12')

sns.boxplot(x="Class", y="V10", data=df2, ax=axes[2])
axes[2].set_title('V10')

sns.boxplot(x="Class", y="V16", data=df2, ax=axes[3])
axes[3].set_title('V16')

sns.boxplot(x="Class", y="V3", data=df2, ax=axes[4])
axes[4].set_title('V3')

plt.show()

# %%
# 5 Most Positive Correlation Variables
fig, axes = plt.subplots(ncols=5, figsize=(20,8))

sns.boxplot(x="Class", y="V4", data=df2, ax=axes[0])
axes[0].set_title('V4')

sns.boxplot(x="Class", y="V11", data=df2, ax=axes[1])
axes[1].set_title('V11')

sns.boxplot(x="Class", y="V2", data=df2, ax=axes[2])
axes[2].set_title('V2')

sns.boxplot(x="Class", y="V19", data=df2, ax=axes[3])
axes[3].set_title('V19')

sns.boxplot(x="Class", y="V20", data=df2, ax=axes[4])
axes[4].set_title('V20')

plt.show()

# %%
# Raw Data Correlation
mask = np.zeros_like(df2.corr())
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(36,30))
sns.heatmap(df2.corr(), mask=mask, annot=True, vmin=-1, vmax=1, cmap='Spectral')

b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values

plt.savefig('images/heatmapall2.png')

# %%
df2.to_csv('datasets/creditcard_oversample.csv', index=False)

# %%
df2['Class'].value_counts()
# Out:
# 1    284315
# 0    284315
# Name: Class, dtype: int64

# %%
df2['Class'].value_counts(normalize=True)
# Out:
# 1    0.5
# 0    0.5
# Name: Class, dtype: float64

# %%
df2.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62      0
# 1    2.69      0
# 2  378.66      0
# 3  123.50      0
# 4   69.99      0

# %%
df2.loc[df2['Class'] == 1, 'Class'].count()
# Out:
# 284315

# %%
df2.loc[df2['Class'] == 0, 'Class'].count()
# Out:
# 284315

# %%
plt.figure(figsize=(12,5))

plt.style.use('fivethirtyeight')
# df2['Class'].value_counts().plot(kind='barh')
sns.countplot(y='Class', data=df2);
plt.title('Count of Classes');
plt.xlabel('');

# %%
train_df = df.sample(frac=0.8, random_state=100)
test_df = df[~df.index.isin(train_df.index)]

# %%
train_df['Class'].value_counts()
# Out:
# 0    227442
# 1       404
# Name: Class, dtype: int64

# %%
test_df['Class'].value_counts()
# Out:
# 0    56873
# 1       88
# Name: Class, dtype: int64

# %%
amt = len(train_df[train_df['Class'] == 0]) - len(train_df[train_df['Class'] == 1])
amt
# Out:
# 227038

# %%
df_sample = train_df[train_df['Class'] == 1].sample(amt, replace=True, random_state=42)
df_over = pd.concat([df_sample, train_df])

# %%
df_over.to_csv('datasets/oversample_credit_training.csv', index=False)
test_df.to_csv('datasets/oversample_credit_testing.csv', index=False)

# %% [markdown]
# # Create Undersampling Dataset(s)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62      0
# 1    2.69      0
# 2  378.66      0
# 3  123.50      0
# 4   69.99      0

# %%
amt = len(df[df['Class'] == 1])
amt
# Out:
# 492

# %%
df_frauds = df[df['Class'] == 1].copy()
df_frauds.shape
# Out:
# (492, 31)

# %%
df_sample = df[df['Class'] == 0].sample(amt, replace=False, random_state=42)
df_sample.shape
# Out:
# (492, 31)

# %%
df_sample.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 138028   82450.0  1.314539  0.590643 -0.666593  0.716564  0.301978 -1.125467
# 63099    50554.0 -0.798672  1.185093  0.904547  0.694584  0.219041 -0.319295
# 73411    55125.0 -0.391128 -0.245540  1.122074 -1.308725 -0.639891  0.008678
# 164247  116572.0 -0.060302  1.065093 -0.987421 -0.029567  0.176376 -1.348539
# 148999   90434.0  1.848433  0.373364  0.269272  3.866438  0.088062  0.970447
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 138028  0.388881 -0.288390 -0.132137 -0.597739 -0.325347 -0.216435  0.084204
# 63099   0.495236  0.139269 -0.760214  0.170547  0.821998  0.468322 -0.057550
# 73411  -0.701304 -0.027315 -2.628854  2.051312  0.575866 -0.594037  1.097880
# 164247  0.775644  0.134843 -0.149734 -1.238598 -0.841133 -0.586472 -0.779620
# 148999 -0.721945  0.235983  0.683491  1.166335  1.297531 -1.920966  1.885047
#
#              V14       V15       V16       V17       V18       V19       V20  \
# 138028 -1.054631  0.967932  0.601226  0.631117  0.295078 -0.136151 -0.058040
# 63099   0.573006  0.358688 -0.011633 -0.504570  0.722750  0.861541 -0.081298
# 73411  -0.338340  0.617523 -0.756390  0.535141  1.016704  2.133828  0.065716
# 164247 -0.436671  0.747871  0.266437  0.703234  0.916719 -0.189967 -0.169706
# 148999  1.323225 -2.044482  1.317655 -0.441076  0.804104 -1.658339 -0.282777
#
#              V21       V22       V23       V24       V25       V26       V27  \
# 138028 -0.170307 -0.429655 -0.141341 -0.200195  0.639491  0.399476 -0.034321
# 63099   0.202287  0.578699 -0.092245  0.013723 -0.246466 -0.380057 -0.396030
# 73411  -0.133485  0.117403 -0.191748 -0.488642 -0.309774  0.008100  0.163716
# 164247  0.355576  0.907570 -0.018454 -0.126269 -0.339923 -0.150285 -0.023634
# 148999  0.103563  0.620954  0.197077  0.692392 -0.206530 -0.021328 -0.019823
#
#              V28  Amount  Class
# 138028  0.031692    0.76      0
# 63099  -0.112901    4.18      0
# 73411   0.239582   15.00      0
# 164247  0.042330   57.00      0
# 148999 -0.042682    0.00      0

# %%
df2 = pd.concat([df_frauds, df_sample])

# %%
def heatmap_class(df):
    plt.figure(figsize=(8,16))
    sns.heatmap(df.corr()[['Class']].drop(index=['Class','Time','Amount']).sort_values(by='Class', ascending=False), annot=True, vmin=-1, vmax=1, cmap='Spectral')
    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values
    #Vmin and Vmax are making it so it diverges on 0, not how it was

def heatmap_all(df):
    mask = np.zeros_like(df.corr())
    mask[np.triu_indices_from(mask)] = True

    plt.figure(figsize=(36,30))
    sns.heatmap(df.corr(), mask=mask, annot=True, vmin=-1, vmax=1, cmap='Spectral')

    b, t = plt.ylim() # discover the values for bottom and top
    b += 0.5 # Add 0.5 to the bottom
    t -= 0.5 # Subtract 0.5 from the top
    plt.ylim(b, t) # update the ylim(bottom, top) values

# %%
# Correlation against 'Class'
plt.figure(figsize=(8,16))
sns.heatmap(df2.corr()[['Class']].drop(index=['Class','Time','Amount']).sort_values(by='Class', ascending=False), annot=True, vmin=-1, vmax=1, cmap='Spectral')
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
#Vmin and Vmax are making it so it diverges on 0, not how it was

plt.savefig('images/heatmapclass3.png')

# %%
# Raw Data Correlation
mask = np.zeros_like(df2.corr())
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(36,30))
sns.heatmap(df2.corr(), mask=mask, annot=True, vmin=-1, vmax=1, cmap='Spectral')

b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values

plt.savefig('images/heatmapall3.png')

# %%
df2.to_csv('datasets/credit_undersample_42.csv', index=False)

# %%
df_sample = df[df['Class'] == 0].sample(amt, replace=False, random_state=79)
df2 = pd.concat([df_frauds, df_sample])
df2.to_csv('datasets/credit_undersample_79.csv', index=False)

# %%
heatmap_class(df2)

# %%
heatmap_all(df2)

# %%
df_sample = df[df['Class'] == 0].sample(amt, replace=False, random_state=20200304)
df2 = pd.concat([df_frauds, df_sample])
df2.to_csv('datasets/credit_undersample_20200304.csv', index=False)

# %%
heatmap_class(df2)

# %%
heatmap_all(df2)

# %%
df_sample = df[df['Class'] == 0].sample(amt, replace=False, random_state=20200202)
df2 = pd.concat([df_frauds, df_sample])
df2.to_csv('datasets/credit_undersample_20200202.csv', index=False)

# %%
heatmap_class(df2)

# %%
heatmap_all(df2)

# %%
df_sample = df[df['Class'] == 0].sample(amt, replace=False, random_state=804)
df2 = pd.concat([df_frauds, df_sample])
df2.to_csv('datasets/credit_undersample_804.csv', index=False)

# %%
heatmap_class(df2)

# %%
heatmap_all(df2)

# %% [markdown]
# #### Extra Test Graphs

# %%
df.keys().drop(['Time', 'Amount', 'Class'])
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28'],
#       dtype='object')

# %%
variables_1 = ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14']
variables_2 = ['V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28']

# %%
df_box1 = pd.DataFrame(data = df, columns = variables_1)
plt.figure(figsize=(16,8))
df_box1.boxplot();

# %%
df_box2 = pd.DataFrame(data = df, columns = variables_2)
plt.figure(figsize=(16,8))
df_box2.boxplot();
